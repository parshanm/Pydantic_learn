# %%
from pydantic import BaseModel, ValidationError, ConfigDict

# %% [markdown]
# # Validating default values

# %%
class User(BaseModel):
    model_config = ConfigDict(validate_default=True)

    username: str = None
    password: str = None
    email: str = None

# %%
try:
    User()
except ValidationError as e:
    print(e)
# Out:
# 3 validation errors for User
# username
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.13/v/string_type
# password
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.13/v/string_type
# email
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.13/v/string_type

# %% [markdown]
# Yeah it makes an error 🥸😊

# %% [markdown]
# # Data Validation for assigment data

# %% [markdown]
# Now if i make an usual model:

# %%
class User(BaseModel):
    username: str
    password: str
    email: str

# %%
user = User(username="admin", password="", email="")
user
# Out:
# User(username='admin', password='', email='')

# %% [markdown]
# But if I assign data like this:

# %%
user.email = 100

# %% [markdown]
# Yep! It's not going to raise an exception,
# But we can fix this with ConfigDict

# %%
class User(BaseModel):
    model_config = ConfigDict(validate_assignment=True)

    username: str
    password: str
    email: str

# %%
user = User(username="admin", password="", email="")
user
# Out:
# User(username='admin', password='', email='')

# %%
try:
    user.email = 100
except ValidationError as e:
    print(e)
# Out:
# 1 validation error for User
# email
#   Input should be a valid string [type=string_type, input_value=100, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.13/v/string_type

# %% [markdown]
# # And its Done.....
